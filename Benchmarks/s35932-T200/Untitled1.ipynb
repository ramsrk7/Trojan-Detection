# %%
import progressbar as pb

# %%
#import libraries
import progressbar as pb

#define progress timer class
class progress_timer:

    def __init__(self, n_iter, description="Something"):
        self.n_iter         = n_iter
        self.iter           = 0
        self.description    = description + ': '
        self.timer          = None
        self.initialize()

    def initialize(self):
        #initialize timer
        widgets = [self.description, pb.Percentage(), ' ',   
                   pb.Bar(marker=pb.RotatingMarker()), ' ', pb.ETA()]
        self.timer = pb.ProgressBar(widgets=widgets, maxval=self.n_iter).start()

    def update(self, q=1):
        #update timer
        self.timer.update(self.iter)
        self.iter += q

    def finish(self):
        #end timer
        self.timer.finish()

# %%
#initialize
pt = progress_timer(description= 'For loop example', n_iter=1000000)
#for loop example
for i in range(0,1000000):
    #update
    pt.update()
#finish
pt.finish()
# Out:
# For loop example: 100% |||||||||||||||||||||||||||||||||||||||||| Time: 0:00:01

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
# from tqdm.auto import tqdm  # for notebooks

df = pd.DataFrame(np.random.randint(0, int(1e8), (10000, 1000)))

# Create and register a new `tqdm` instance with `pandas`
# (can use tqdm_gui, optional kwargs, etc.)
tqdm.pandas()

# Now you can use `progress_apply` instead of `apply`
df.groupby(0).progress_apply(lambda x: x**2)
# Out:
# 100%|██████████| 10000/10000 [00:03<00:00, 2630.08it/s]
#                    0                 1                 2                 3    \
# 0      483492021356304  7853215678693641   658813677377956  9760952922076225
# 1      811226374705296   491336698525456   234499576397641  4735977133486096
# 2     5100296618482321   119581835881104  8992893904956900    11274840986809
# 3     2298685244495236   685275380395225  9253773346006225  2443563356137744
# 4      427843782828225   560439100224025  2110912333851556  1864411014738276
# 5     2355105090830625  9753027807541561  1447471712196409   649684736899396
# 6     4799160712200625  3714407846267364   749133267349401  1573428842260900
# 7     6114250340843584     3436266716089  4650424090984324  9043683239351524
# 8     4919090478067984  9315842076332100     5653105395876  7614791028072900
# 9     9795215689691524   140651891105625  7032284081451225   919120307098009
# ...

# %%
import swifter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-dee83308f566> in <module>()
# ----> 1 import swifter
#
# ModuleNotFoundError: No module named 'swifter'

# %%
import dask.dataframe as dd
import multiprocessing
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/dask/array/__init__.py in <module>()
#       2     from .blockwise import blockwise, atop
# ----> 3     from .core import (
#       4         Array,
#
# /usr/local/lib/python3.7/site-packages/dask/array/core.py in <module>()
#      28 from . import chunk
# ---> 29 from .. import config, compute
#      30 from ..base import (
#
# ImportError: cannot import name 'compute' from 'dask' (/usr/local/lib/python3.7/site-packages/dask/__init__.py)
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/dask/dataframe/__init__.py in <module>()
#       1 try:
# ----> 2     from .core import (
#       3         DataFrame,
#
# ...

# %%
import dask

# %%
dask.__version__
# Out:
# '2.9.2'

# %%
from pandarallel import pandarallel
from math import sin

# %%
import multiprocessing as mp

# %%
mp.cpu_count()
# Out:
# 4

# %%
pool = mp.Pool(mp.cpu_count())
# Out:
# Process ForkPoolWorker-12:
# Process ForkPoolWorker-13:
# Process ForkPoolWorker-11:
# Process ForkPoolWorker-10:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
# ...

# %%
def howmany_within_range(row, minimum, maximum):
    """Returns how many numbers lie within `maximum` and `minimum` in a given `row`"""
    count = 0
    for n in row:
        if minimum <= n <= maximum:
            count = count + 1
    return count

# %%
import numpy as np
from time import time

# Prepare data
np.random.RandomState(100)
arr = np.random.randint(0, 10, size=[200000, 5])
data = arr.tolist()
data[:5]
# Out:
# [[1, 8, 1, 1, 2],
#  [1, 0, 4, 6, 6],
#  [9, 1, 0, 9, 5],
#  [0, 9, 8, 9, 9],
#  [0, 8, 0, 6, 1]]

# %%
# Step 2: `pool.apply` the `howmany_within_range()`
results = [pool.apply(howmany_within_range, args=(row, 4, 8)) for row in data]

# Step 3: Don't forget to close
pool.close()    

print(results[:10])
# Out:
# Process ForkPoolWorker-5:
# Traceback (most recent call last):
#   File "/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 297, in _bootstrap
#     self.run()
#   File "/usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/process.py", line 99, in run
#     self._target(*self._args, **self._kwargs)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-ccec920945a3> in <module>()
#       1 # Step 2: `pool.apply` the `howmany_within_range()`
# ----> 2 results = [pool.apply(howmany_within_range, args=(row, 4, 8)) for row in data]
#       3
#       4 # Step 3: Don't forget to close
#       5 pool.close()
#
# <ipython-input-23-ccec920945a3> in <listcomp>(.0)
#       1 # Step 2: `pool.apply` the `howmany_within_range()`
# ...

# %%
import numpy as np
from multiprocessing import cpu_count, Pool
 
cores = cpu_count() #Number of CPU cores on your system
partitions = cores #Define as many partitions as you want
 
def parallelize(data, func):
    data_split = np.array_split(data, partitions)
    pool = Pool(cores)
    data = pd.concat(pool.map(func, data_split))
    pool.close()
    pool.join()
    return data

# %%
import pandas as pd

# %%
new = pd.read_csv("new")

# %%
def pout_func(nets,level=1):
    t = []

    if isinstance(nets,list):
        for i in nets:
            #print("Checking ",i)
            val,temp = match(i)
            if val == 1:
                #print("Got it")
                t.extend(temp)
                t = list(dict.fromkeys(t))
            else:
                return level
            
    elif isinstance(nets,str):
        #print("Checking ",nets)
        val, temp = match_pout(nets)
        if val == 1:
            t.extend(temp)
        else:
            return level                     #Return 0 when no instance is found
        
    t = list(filter(None,t)) 
    
    
    #print("\n\n\n\n")
    level = level+1
    #print("Im here",level+1)
    return pout_func(t,level)          #Recursive function for moving forwards to the given level

# %%
#Function to find the next set of nets

def match_pout(net):      
    net_t = "(" + net + ")"
    temp = new[new['Inputs'].str.contains(net_t, regex=False)]
    if temp.empty == False:
        #print("Running")
        return 1,list(temp['Net'].values)
    else:
        try:
            pt.update()
            return 0,None
        except:
            return 0,None

# %%
#Function to find the next set of nets

def match(net):      
    net_t = "(" + net + ")"
    temp = new[new['Inputs'].str.contains(net_t, regex=False)]
    if temp.empty == False:
        #print(temp[['Type','Inputs','Net']])
        return 1,list(temp['Net'].values)
    else:
        return 0,None

# %%
data = parallelize(new['Net'], pout_func);
# Out:
# Process ForkPoolWorker-40:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-b5864f96b0dd> in <module>()
# ----> 1 data = parallelize(new['Net'], pout_func);
#
# <ipython-input-35-86b703c50397> in parallelize(data, func)
#       8     data_split = np.array_split(data, partitions)
#       9     pool = Pool(cores)
# ---> 10     data = pd.concat(pool.map(func, data_split))
#      11     pool.close()
#      12     pool.join()
#
# /usr/local/Cellar/python/3.7.0/Frameworks/Python.framework/Versions/3.7/lib/python3.7/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     266         in a list that is returned.
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#     270     def starmap(self, func, iterable, chunksize=None):
#
# ...

# %%
def ex(hello):
    return 1

# %%
import sys
sys.setrecursionlimit(100000)
